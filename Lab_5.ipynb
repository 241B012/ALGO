# %% [markdown]
# <a href="https://colab.research.google.com/github/241B012/ALGO/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt

# Selection Sort Algorithm
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        # Swap
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

n = int(input("Enter number of elements: "))

numbers = []
for i in range(n):
    num = int(input(f"Enter element {i+1}: "))
    numbers.append(num)

print("Original List:", numbers)

start_time = time.time()
sorted_list = selection_sort(numbers)
end_time = time.time()

print("Sorted List:", sorted_list)

running_time = end_time - start_time
print(f"Running Time: {running_time:.6f} seconds")

sizes = [10, 50, 100, 200, 500]
times = []

for size in sizes:
    test_list = list(range(size, 0, -1))
    start = time.time()
    selection_sort(test_list)
    end = time.time()
    times.append(end - start)

plt.plot(sizes, times, marker='o')
plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (seconds)")
plt.title("Selection Sort Performance")
plt.show()
# Out:
# Enter number of elements: 10
# Enter element 1: 12
# Enter element 2: 13
# Enter element 3: 24
# Enter element 4: 56
# Enter element 5: 87
# Enter element 6: 98
# Enter element 7: 90
# Enter element 8: 45
# Enter element 9: 72
# Enter element 10: 81
# Original List: [12, 13, 24, 56, 87, 98, 90, 45, 72, 81]
# Sorted List: [12, 13, 24, 45, 56, 72, 81, 87, 90, 98]
# Running Time: 0.000080 seconds

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

# Merge Sort Implementation done
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Measuring  running time of the code
sizes = [100, 500, 1000, 5000, 10000, 20000]
times = []

for n in sizes:
    arr = [random.randint(0, 100000) for _ in range(n)]
    start = time.time()
    merge_sort(arr)
    end = time.time()
    times.append(end - start)

# Plot graph
plt.figure(figsize=(8,5))
plt.plot(sizes, times, marker='o', linestyle='-', color='b')
plt.title("Merge Sort Running Time")
plt.xlabel("Input Size (n)")
plt.ylabel("Time (seconds)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.import time
import random
import matplotlib.pyplot as plt

# Quick Sort Implementation
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[len(arr) // 2]   # choose middle element as pivot
        left = [x for x in arr if x < pivot]
        middle = [x for x in arr if x == pivot]
        right = [x for x in arr if x > pivot]
        return quick_sort(left) + middle + quick_sort(right)

# Measure running time
sizes = [100, 500, 1000, 5000, 10000, 20000]
times = []

for n in sizes:
    arr = [random.randint(0, 100000) for _ in range(n)]
    start = time.time()
    quick_sort(arr)
    end = time.time()
    times.append(end - start)

# Plot graph
plt.figure(figsize=(8,5))
plt.plot(sizes, times, marker='o', linestyle='-', color='r')
plt.title("Quick Sort Running Time")
plt.xlabel("Input Size (n)")
plt.ylabel("Time (seconds)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables

import time
import matplotlib.pyplot as plt

# Selection sort implementation
def selection_sort(arr):
    for i in range(len(arr)):
        min_ = i
        for j in range(i, len(arr)):
            if arr[min_] > arr[j]:
                min_ = j
        arr[i], arr[min_] = arr[min_], arr[i]
    return arr

# Example list
arr = [5,4,3,2,1,245,67,78,3,245,96,45,56,13,76,13,5,13,3,436,673,465,334,4364,334,3743,46]

# Timing on the small example
st = time.time()
sorted_list = selection_sort(arr.copy())
et = time.time()
print("Time for small list:", et - st)

# Running time for different sizes
time_arr = []
sizes = [100, 1000, 5000,10000,15000,20000,30000]  # 10,000 will be very slow for selection sort

for s in sizes:
    test_arr = list(range(s, 0, -1))  # worst-case descending order
    st = time.time()
    selection_sort(test_arr)
    et = time.time()
    time_arr.append(et - st)
    print(f"Size {s}: {et - st:.4f} seconds")

# Plotting
plt.plot(sizes, time_arr, marker='o')
plt.xlabel("Input size (n)")
plt.ylabel("Running time (seconds)")
plt.title("Selection Sort Running Time")
plt.grid(True)
plt.show()
# Out:
# Time for small list: 8.153915405273438e-05
# Size 100: 0.0002 seconds
# Size 1000: 0.0271 seconds
# Size 5000: 0.6414 seconds
# Size 10000: 2.5643 seconds
# Size 15000: 6.8824 seconds
# Size 20000: 11.4637 seconds
# Size 30000: 25.4004 seconds

# %%
# Creating a random value (uniform)
import time
import matplotlib.pyplot as plt

# Quick sort implementation
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]  # choose middle element as pivot
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Example list
arr = [5,4,3,2,1,245,67,78,3,245,96,45,56,13,76,13,5,13,3,436,673,465,334,4364,334,3743,46]

# Timing on the small example
st = time.time()
sorted_list = quick_sort(arr.copy())
et = time.time()
print("Time for small list:", et - st)

# Running time for different sizes
time_arr = []
sizes = [100, 1000, 5000, 10000, 20000,50000,100000000]

for s in sizes:
    test_arr = list(range(s, 0, -1))  # worst-case descending order
    st = time.time()
    quick_sort(test_arr)
    et = time.time()
    time_arr.append(et - st)
    print(f"Size {s}: {et - st:.6f} seconds")

# Plotting
plt.plot(sizes, time_arr, marker='o', label="Quick Sort")
plt.xlabel("Input size (n)")
plt.ylabel("Running time (seconds)")
plt.title("Quick Sort Running Time")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Time for small list: 0.00010943412780761719
# Size 100: 0.000090 seconds
# Size 1000: 0.000912 seconds
# Size 5000: 0.007006 seconds
# Size 10000: 0.013822 seconds
# Size 20000: 0.025068 seconds
# Size 50000: 0.069059 seconds
# Size 100000000: 253.744245 seconds

# %%
a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    selection.sort()
    c_time.append((timeit.default_timer() - start_time) * 1000)

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-716276353.py in <cell line: 0>()
#       1 # Plotting results
#       2 plt.figure(figsize=(10, 5))
# ----> 3 plt.plot(a_time, linewidth = 1, marker="o")
#       4 plt.plot(b_time, linewidth = 1, marker="o")
#       5 plt.plot(c_time, linewidth = 1, marker="o")
#
# NameError: name 'a_time' is not defined
